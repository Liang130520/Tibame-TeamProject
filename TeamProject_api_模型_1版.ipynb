# %% [markdown]
# <a href="https://colab.research.google.com/github/Liang130520/Tibame-TeamProject/blob/main/TeamProject_api_%E6%A8%A1%E5%9E%8B_1%E7%89%88.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from urllib.request import urlretrieve
from sklearn.datasets import load_boston

# url = "http://lib.stat.cmu.edu/datasets/boston"
# urlretrieve(url, "test.csv")

shilin_111_data = pd.read_csv("shilin_111_house.csv", encoding = "utf-8")
df = pd.DataFrame(shilin_111_data)
df["ans"] = df["tp"]

pd.set_option('display.max_columns', 500)
df
# Out:
#     AA11                b      bs city           e el   fi     g  j  k  l  \
# 0      住     公寓(5樓含以下無電梯)   87.39    A  2022-10-03  無 -1.0  41.0  1  1  0
# 1      住     公寓(5樓含以下無電梯)   82.82    A  2022-09-15  無 -1.0  42.0  1  1  0
# 2      住     公寓(5樓含以下無電梯)   86.80    A  2022-09-01  無 -1.0  43.0  1  1  0
# 3     其他  住宅大樓(11層含以上有電梯)   52.85    A  2022-09-10  有 -1.0  17.0  1  1  1
# 4      住     公寓(5樓含以下無電梯)   87.26    A  2022-09-30  無 -1.0  47.0  1  1  0
# ..   ...              ...     ...  ...         ... ..  ...   ... .. .. ..
# 984    住    華廈(10層含以下有電梯)  100.00    A  2022-01-16  有 -1.0  42.0  1  1  0
# 985    住     公寓(5樓含以下無電梯)  100.00    A  2022-01-12  無 -1.0  47.0  1  1  0
# 986    住    華廈(10層含以下有電梯)   78.55    A  2022-01-20  有 -1.0  43.0  1  1  0
# 987    住     公寓(5樓含以下無電梯)   84.89    A  2022-01-01  無 -1.0  38.0  1  1  0
# 988    商    華廈(10層含以下有電梯)   84.49    A  2022-01-17  有 -1.0  42.0  1  1  0
#
#            lat         lon  m     msg         p   pu    r      s  \
# ...

# %%
df = df.drop(["e"], axis = 1)
df
# Out:
#     AA11                b      bs city el   fi     g  j  k  l        lat  \
# 0      住     公寓(5樓含以下無電梯)   87.39    A  無 -1.0  41.0  1  1  0  25.089290
# 1      住     公寓(5樓含以下無電梯)   82.82    A  無 -1.0  42.0  1  1  0  25.090464
# 2      住     公寓(5樓含以下無電梯)   86.80    A  無 -1.0  43.0  1  1  0  25.106244
# 3     其他  住宅大樓(11層含以上有電梯)   52.85    A  有 -1.0  17.0  1  1  1  25.099639
# 4      住     公寓(5樓含以下無電梯)   87.26    A  無 -1.0  47.0  1  1  0  25.092406
# ..   ...              ...     ...  ... ..  ...   ... .. .. ..        ...
# 984    住    華廈(10層含以下有電梯)  100.00    A  有 -1.0  42.0  1  1  0  25.126048
# 985    住     公寓(5樓含以下無電梯)  100.00    A  無 -1.0  47.0  1  1  0  25.112558
# 986    住    華廈(10層含以下有電梯)   78.55    A  有 -1.0  43.0  1  1  0  25.081422
# 987    住     公寓(5樓含以下無電梯)   84.89    A  無 -1.0  38.0  1  1  0  25.103837
# 988    商    華廈(10層含以下有電梯)   84.49    A  有 -1.0  42.0  1  1  0  25.118690
#
#             lon  m     msg         p   pu    r      s             t        tp  \
# ...

# %%
" 做 One_Hot Encoding "
# 類別值:AA11, b, city, el, m, msg, pu, t, twn, type
# 未知定義, 先當類別:el, m
pd.set_option('display.max_columns', 500)
df = pd.get_dummies(df)
# df = pd.get_dummies(df, columns = ["pu"])
df

import numpy as np
x = np.array(df.drop(['p','tp','ans'], axis = 1))
y = np.array(df["ans"])

from sklearn.model_selection import train_test_split
# [90%x, 10%x, 90%y, 10%y]
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.1)

from sklearn.tree import DecisionTreeRegressor
reg = DecisionTreeRegressor(max_depth=4)
reg.fit(x_train, y_train)

import matplotlib.pyplot as plt
from sklearn.tree import plot_tree
plt.figure(figsize=(15, 15))
plot_tree(reg, 
     filled=True,
     max_depth=2)

from sklearn.metrics import r2_score
pre = reg.predict(x_test)
r2_score(y_test, pre)
# Out:
# 0.8098623679727464
