# %% [markdown]
# <a href="https://colab.research.google.com/github/Liang130520/Tibame-TeamProject/blob/main/%E6%96%B0%E7%89%B9%E5%BE%B5_%E5%85%AC%E5%B0%BA%E5%85%A7%E8%A8%AD%E6%96%BD%E6%95%B8%E9%87%8F_%E9%9B%B2%E7%AB%AF_%E5%9B%BA%E5%AE%9A%E8%B7%9D%E9%9B%A2_1126.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
'''
使用前注意事項:
以下兩個檔案須注意路徑與名稱

台北市房屋交易+特徵表需放在固定資料夾
/content/drive/MyDrive/程式語言/特徵檔案/

1.主檔案 : 台北市房屋交易_all_standard&Normal.csv
2.項設施座標 : 設施座標表Ver2.xlsx

使用方式:
針對所需要修改設施選擇後再輸入距離即可(單位為公里)

'''

import pandas as pd
import geopy.distance
from google.colab import files
import os
from google.colab import drive

drive.mount('/content/drive')
os.chdir('/content/drive/MyDrive/程式語言/特徵檔案') #切換該目錄
os.listdir()

# name = input("請輸入名字後兩字：")
name = "博翔"

# 載入房屋交易csv檔

dh = pd.read_csv(str(name) + "/台北市房屋交易_for_model_1126_加設施_3.csv", encoding = "utf-8")
pd.set_option('display.max_columns', 100)


#================= 1.公園 =============
def park():
  if int(pa) == 0 :
    pass
  if int(pa) != 0 :

  # 載入設施csv檔
    df = pd.read_excel("/content/drive/MyDrive/程式語言/特徵檔案/設施座標表Ver2.xlsx", sheet_name="公園") 
    
    dh["固定範圍(公園)"]=int(pa)/1000
    dh["公園數量"]=""
    for i in range(len(dh)):
        times = 0
        origin_lat = str(dh["緯度"][i])
        origin_long = str(dh["經度"][i])
        origin = (origin_lat, origin_long)
        for j in range(len(df)):
            destination_lat = str(df["lat"][j])
            destination_long = str(df["lng"][j])
            destination = (destination_lat, destination_long)
            distance=geopy.distance.geodesic(origin, destination).km
            try:
                if distance <= int(pa)/1000:
                    times = times + 1
                    
            except:
                print(i,"error")
        dh.at[i,"公園數量"] = times

#================= 2.博物館 =============
def mu():
  if int(m) == 0 :
    pass
  if int(m) != 0 :

    # 載入設施csv檔
    df = pd.read_excel("/content/drive/MyDrive/程式語言/特徵檔案/設施座標表Ver2.xlsx", sheet_name="博物館")  

    dh["固定範圍(博物館)"]=int(m)/1000
    dh["博物館數量"]=""
    for i in range(len(dh)):
        times = 0
        origin_lat = str(dh["緯度"][i])
        origin_long = str(dh["經度"][i])
        origin = (origin_lat, origin_long)
        for j in range(len(df)):
            destination_lat = str(df["lat"][j])
            destination_long = str(df["lng"][j])
            destination = (destination_lat, destination_long)
            distance=geopy.distance.geodesic(origin, destination).km
            try:
                if distance <= int(m)/1000:
                    times = times + 1
                    
            except:
                print(i,"error")
        dh.at[i,"博物館數量"] = times

#================= 3.圖書館 =============
def lib():
  if int(li) == 0 :
    pass
  if int(li) != 0 :

    # 載入設施csv檔
    df = pd.read_excel("/content/drive/MyDrive/程式語言/特徵檔案/設施座標表Ver2.xlsx", sheet_name="圖書館")  

    dh["固定範圍(圖書館)"]=int(li)/1000
    dh["圖書館數量"]=""
    for i in range(len(dh)):
        times = 0
        origin_lat = str(dh["緯度"][i])
        origin_long = str(dh["經度"][i])
        origin = (origin_lat, origin_long)
        for j in range(len(df)):
            destination_lat = str(df["lat"][j])
            destination_long = str(df["lng"][j])
            destination = (destination_lat, destination_long)
            distance=geopy.distance.geodesic(origin, destination).km
            try:
                if distance <= int(li)/1000:
                    times = times + 1
                    
            except:
                print(i,"error")
        dh.at[i,"圖書館數量"] = times

#================= 4.捷運出口數 =============
def mrt():
  if int(mr) == 0 :
    pass
  if int(mr) != 0 :

    # 載入設施csv檔
    df = pd.read_excel("/content/drive/MyDrive/程式語言/特徵檔案/設施座標表Ver2.xlsx", sheet_name="捷運出口")  

    dh["固定範圍(捷運出口)"]=int(mr)/1000
    dh["捷運出口數量"]=""
    for i in range(len(dh)):
        times = 0
        origin_lat = str(dh["緯度"][i])
        origin_long = str(dh["經度"][i])
        origin = (origin_lat, origin_long)
        for j in range(len(df)):
            destination_lat = str(df["lat"][j])
            destination_long = str(df["lng"][j])
            destination = (destination_lat, destination_long)
            distance=geopy.distance.geodesic(origin, destination).km
            try:
                if distance <= int(mr)/1000:
                    times = times + 1
                    
            except:
                print(i,"error")
        dh.at[i,"捷運出口數量"] = times

#================= 5.學校 =============
def edu():
  if int(ed) == 0 :
    pass
  if int(ed) != 0 :
    # 載入設施csv檔
    df = pd.read_excel("/content/drive/MyDrive/程式語言/特徵檔案/設施座標表Ver2.xlsx", sheet_name="學校") 

    dh["固定範圍(學校)"]=int(ed)/1000
    dh["學校數量"]=""
    for i in range(len(dh)):
        times = 0
        origin_lat = str(dh["緯度"][i])
        origin_long = str(dh["經度"][i])
        origin = (origin_lat, origin_long)
        for j in range(len(df)):
            destination_lat = str(df["lat"][j])
            destination_long = str(df["lng"][j])
            destination = (destination_lat, destination_long)
            distance=geopy.distance.geodesic(origin, destination).km
            try:
                if distance <= int(ed)/1000:
                    times = times + 1
                    
            except:
                print(i,"error")
        dh.at[i,"學校數量"] = times

#================= 6.消防 =============
def fire():
  if int(fir) == 0 :
    pass
  if int(fir) != 0 :
    # 載入設施csv檔
    df = pd.read_excel("/content/drive/MyDrive/程式語言/特徵檔案/設施座標表Ver2.xlsx", sheet_name="消防") 

    dh["固定範圍(消防局)"]=int(fir)/1000
    dh["消防局數量"]=""
    for i in range(len(dh)):
        times = 0
        origin_lat = str(dh["緯度"][i])
        origin_long = str(dh["經度"][i])
        origin = (origin_lat, origin_long)
        for j in range(len(df)):
            destination_lat = str(df["lat"][j])
            destination_long = str(df["lng"][j])
            destination = (destination_lat, destination_long)
            distance=geopy.distance.geodesic(origin, destination).km
            try:
                if distance <= int(fir)/1000:
                    times = times + 1
                    
            except:
                print(i,"error")
        dh.at[i,"消防局數量"] = times

#================= 7.禮儀 =============
def dead():
  if int(de) == 0 :
    pass
  if int(de) != 0 :

    # 載入設施csv檔
    df = pd.read_excel("/content/drive/MyDrive/程式語言/特徵檔案/設施座標表Ver2.xlsx", sheet_name="禮儀")  

    dh["固定範圍(禮儀)"]=int(de)/1000
    dh["禮儀數量"]=""
    for i in range(len(dh)):
        times = 0
        origin_lat = str(dh["緯度"][i])
        origin_long = str(dh["經度"][i])
        origin = (origin_lat, origin_long)
        for j in range(len(df)):
            destination_lat = str(df["lat"][j])
            destination_long = str(df["lng"][j])
            destination = (destination_lat, destination_long)
            distance=geopy.distance.geodesic(origin, destination).km
            try:
                if distance <= int(de)/1000:
                    times = times + 1
                    
            except:
                print(i,"error")
        dh.at[i,"禮儀數量"] = times

#================= 8.警察 =============
def pol():
  if int(po) == 0 :
    pass
  if int(po) != 0 :

    # 載入設施csv檔
    df = pd.read_excel("/content/drive/MyDrive/程式語言/特徵檔案/設施座標表Ver2.xlsx", sheet_name="警察")  

    dh["固定範圍(警察局)"]=int(po)/1000
    dh["警察局數量"]=""
    for i in range(len(dh)):
        times = 0
        origin_lat = str(dh["緯度"][i])
        origin_long = str(dh["經度"][i])
        origin = (origin_lat, origin_long)
        for j in range(len(df)):
            destination_lat = str(df["lat"][j])
            destination_long = str(df["lng"][j])
            destination = (destination_lat, destination_long)
            distance=geopy.distance.geodesic(origin, destination).km
            try:
                if distance <= int(po)/1000:
                    times = times + 1
                    
            except:
                print(i,"error")
        dh.at[i,"警察局數量"] = times

#================= 9.郵局 =============
def post():
  if int(pos) == 0 :
    pass
  if int(pos) != 0 :

    # 載入設施csv檔
    df = pd.read_excel("/content/drive/MyDrive/程式語言/特徵檔案/設施座標表Ver2.xlsx", sheet_name="郵局") 

    dh["固定範圍(郵局)"]=int(pos)/1000
    dh["郵局數量"]=""
    for i in range(len(dh)):
        times = 0
        origin_lat = str(dh["緯度"][i])
        origin_long = str(dh["經度"][i])
        origin = (origin_lat, origin_long)
        for j in range(len(df)):
            destination_lat = str(df["lat"][j])
            destination_long = str(df["lng"][j])
            destination = (destination_lat, destination_long)
            distance=geopy.distance.geodesic(origin, destination).km
            try:
                if distance <= int(pos)/1000:
                    times = times + 1
                    
            except:
                print(i,"error")
        dh.at[i,"郵局數量"] = times

#================= 10.金融 =============
def fin():
  if int(fi) == 0 :
    pass
  if int(fi) != 0 :

    # 載入設施csv檔
    df = pd.read_excel("/content/drive/MyDrive/程式語言/特徵檔案/設施座標表Ver2.xlsx", sheet_name="金融")  

    dh["固定範圍(金融)"]=int(fi)/1000
    dh["金融數量"]=""
    for i in range(len(dh)):
        times = 0
        origin_lat = str(dh["緯度"][i])
        origin_long = str(dh["經度"][i])
        origin = (origin_lat, origin_long)
        for j in range(len(df)):
            destination_lat = str(df["lat"][j])
            destination_long = str(df["lng"][j])
            destination = (destination_lat, destination_long)
            distance=geopy.distance.geodesic(origin, destination).km
            try:
                if distance <= int(fi)/1000:
                    times = times + 1
                    
            except:
                print(i,"error")
        dh.at[i,"金融數量"] = times

#================= 11.醫療醫院 =============
def hosp():
  if int(hos) == 0 :
    pass
  if int(hos) != 0 :

    # 載入設施csv檔
    df = pd.read_excel("/content/drive/MyDrive/程式語言/特徵檔案/設施座標表Ver2.xlsx", sheet_name="醫療醫院")  

    dh["固定範圍(醫院)"]=int(hos)/1000
    dh["醫院數量"]=""
    for i in range(len(dh)):
        times = 0
        origin_lat = str(dh["緯度"][i])
        origin_long = str(dh["經度"][i])
        origin = (origin_lat, origin_long)
        for j in range(len(df)):
            destination_lat = str(df["lat"][j])
            destination_long = str(df["lng"][j])
            destination = (destination_lat, destination_long)
            distance=geopy.distance.geodesic(origin, destination).km
            try:
                if distance <= int(hos)/1000:
                    times = times + 1
                    
            except:
                print(i,"error")
        dh.at[i,"醫院數量"] = times

#================= 12.醫療診所 =============
def clinic():
  if int(cl) == 0 :
    pass
  if int(cl) != 0 :

    # 載入設施csv檔
    df = pd.read_excel("/content/drive/MyDrive/程式語言/特徵檔案/設施座標表Ver2.xlsx", sheet_name="醫療診所")  

    dh["固定範圍(診所)"]=int(cl)/1000
    dh["診所數量"]=""
    for i in range(len(dh)):
        times = 0
        origin_lat = str(dh["緯度"][i])
        origin_long = str(dh["經度"][i])
        origin = (origin_lat, origin_long)
        for j in range(len(df)):
            destination_lat = str(df["lat"][j])
            destination_long = str(df["lng"][j])
            destination = (destination_lat, destination_long)
            distance=geopy.distance.geodesic(origin, destination).km
            try:
                if distance <= int(cl)/1000:
                    times = times + 1
                    
            except:
                print(i,"error")
        dh.at[i,"診所數量"] = times

#================= 13.醫療藥局 =============
def pharmacy():
  if int(ph) == 0 :
    pass
  if int(ph) != 0 :

    # 載入設施csv檔
    df = pd.read_excel("/content/drive/MyDrive/程式語言/特徵檔案/設施座標表Ver2.xlsx", sheet_name="醫療藥局")  

    dh["固定範圍(藥局)"]=int(ph)/1000
    dh["藥局數量"]=""
    for i in range(len(dh)):
        times = 0
        origin_lat = str(dh["緯度"][i])
        origin_long = str(dh["經度"][i])
        origin = (origin_lat, origin_long)
        for j in range(len(df)):
            destination_lat = str(df["lat"][j])
            destination_long = str(df["lng"][j])
            destination = (destination_lat, destination_long)
            distance=geopy.distance.geodesic(origin, destination).km
            try:
                if distance <= int(ph)/1000:
                    times = times + 1
                    
            except:
                print(i,"error")
        dh.at[i,"藥局數量"] = times

#主程式

list1=("1公園","2博物館","3圖書館","4捷運出口","5學校","6消防","7禮儀","8警察","9郵局","10醫療","11金融")
print(list1)
print("請輸入每個設施的距離(不要更動請按0):")
# pa=input("公園距離:")
# m=input("博物館距離:")
# li=input("圖書館距離:")
# mr=input("捷運出口距離:")
# ed=input("學校距離:")
# fir=input("消防距離:")
# de=input("禮儀距離:")
# po=input("警察距離:")
# pos=input("郵局距離:")
# fi=input("金融距離:")
# hos=input("醫院距離:")
# cl=input("診所距離:")
# ph=input("藥局距離:")
pa=3000
m=10000
li=5000 
mr=1000
ed=2000
fir=2000
de=5000 
po=500
pos=500
fi=500
hos=1000
cl=500
ph=500

park()   
mu() 
lib() 
mrt() 
edu() 
fire() 
dead() 
pol() 
post()
fin()  
hosp()  
clinic()
pharmacy() 
 
dh.to_csv(str(name) +"4.csv", encoding = "utf-8", index=False)  # 輸入檔名儲存
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# ('1公園', '2博物館', '3圖書館', '4捷運出口', '5學校', '6消防', '7禮儀', '8警察', '9郵局', '10醫療', '11金融')
# 請輸入每個設施的距離(不要更動請按0):
